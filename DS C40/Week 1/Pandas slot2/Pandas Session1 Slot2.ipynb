# %%
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\program files\python37\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# np.NaN: Not an Integer

# %%
dict1={"Name":['Inder',"Alok","Amogh","Rajat","Rahul"],"Income":[1000,2000,1250,1500,np.NaN],
       "Credit_Score":[700,800,670,830,np.NaN]}
dict1
# Out:
# {'Name': ['Inder', 'Alok', 'Amogh', 'Rajat', 'Rahul'],
#  'Income': [1000, 2000, 1250, 1500, nan],
#  'Credit_Score': [700, 800, 670, 830, nan]}

# %%
df=pd.DataFrame(dict1)
df
# Out:
#     Name  Income  Credit_Score
# 0  Inder  1000.0         700.0
# 1   Alok  2000.0         800.0
# 2  Amogh  1250.0         670.0
# 3  Rajat  1500.0         830.0
# 4  Rahul     NaN           NaN

# %%
"123 234 345 567 574".split()
# Out:
# ['123', '234', '345', '567', '574']

# %%
# df['Aadhaar_Id']="123 234 345 567 574".split()
df['Aadhaar_Id']=[123,234,345,567,574]
df.set_index('Aadhaar_Id',inplace=True)
df
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0
# 345         Amogh  1250.0         670.0
# 567         Rajat  1500.0         830.0
# 574         Rahul     NaN           NaN

# %%
df.head(2)
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0

# %%
df.tail(2)
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 567         Rajat  1500.0         830.0
# 574         Rahul     NaN           NaN

# %%
df
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0
# 345         Amogh  1250.0         670.0
# 567         Rajat  1500.0         830.0
# 574         Rahul     NaN           NaN

# %%
print("Dropping the NaN values along the rows")
df.dropna(axis=0) #axis 0 is used for rows
# Out:
# Dropping the NaN values along the rows
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0
# 345         Amogh  1250.0         670.0
# 567         Rajat  1500.0         830.0

# %%
print("Dropping the NaN values along the columns")
df.dropna(axis=1) # axis 1 is used for columns
# Out:
# Dropping the NaN values along the columns
#              Name
# Aadhaar_Id
# 123         Inder
# 234          Alok
# 345         Amogh
# 567         Rajat
# 574         Rahul

# %%
df.columns
# Out:
# Index(['Name', 'Income', 'Credit_Score'], dtype='object')

# %%
print("\n Filling the NaN values in dataframe with some value")
df.fillna(value='Fill Value')
# Out:
#  Filling the NaN values in dataframe with some value
#              Name      Income Credit_Score
# Aadhaar_Id
# 123         Inder      1000.0        700.0
# 234          Alok      2000.0        800.0
# 345         Amogh      1250.0        670.0
# 567         Rajat      1500.0        830.0
# 574         Rahul  Fill Value   Fill Value

# %%
df.index
# Out:
# Int64Index([123, 234, 345, 567, 574], dtype='int64', name='Aadhaar_Id')

# %%
df.notnull()
# Out:
#             Name  Income  Credit_Score
# Aadhaar_Id
# 123         True    True          True
# 234         True    True          True
# 345         True    True          True
# 567         True    True          True
# 574         True   False         False

# %%
df.isnull().sum()
# Out:
# Name            0
# Income          1
# Credit_Score    1
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0
# 345         Amogh  1250.0         670.0
# 567         Rajat  1500.0         830.0
# 574         Rahul     NaN           NaN

# %%
#Q1. Replace the NaN value in Income column with the mean of the column

df['Income']=df['Income'].fillna(value=df['Income'].mean())
df
# Out:
#              Name  Income  Credit_Score
# Aadhaar_Id
# 123         Inder  1000.0         700.0
# 234          Alok  2000.0         800.0
# 345         Amogh  1250.0         670.0
# 567         Rajat  1500.0         830.0
# 574         Rahul  1437.5           NaN

# %%
df['Income'].median()
# Out:
# 1437.5

# %%
data={'Company':['GOOGLE','GOOGLE','MICROSOFT','MICROSOFT','APPLE','APPLE',"TESLA"],
     "Employees":['NAVEEN',"AMOGH","ABHINAV","SHUBHRANIL","Inder","sriranganatharajume","Rohit"],
      "Salary":[1000,1100,1500,1300,1600,2300,2000]}
df=pd.DataFrame(data)
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.groupby('Company').agg({"Salary":['max']})
# Out:
#           Salary
#              max
# Company
# APPLE       2300
# GOOGLE      1100
# MICROSOFT   1500
# TESLA       2000

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df[['Salary','Employees']]
# Out:
#    Salary            Employees
# 0    1000               NAVEEN
# 1    1100                AMOGH
# 2    1500              ABHINAV
# 3    1300           SHUBHRANIL
# 4    1600                Inder
# 5    2300  sriranganatharajume
# 6    2000                Rohit

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.groupby('Company').sum()
# Out:
#            Salary
# Company
# APPLE        3900
# GOOGLE       2100
# MICROSOFT    2800
# TESLA        2000

# %%
df[['Salary','Company','Employees']].groupby('Company')[['Employees','Salary']].max()
# Out:
#                      Employees  Salary
# Company
# APPLE      sriranganatharajume    2300
# GOOGLE                  NAVEEN    1100
# MICROSOFT           SHUBHRANIL    1500
# TESLA                    Rohit    2000

# %%
salary=list(df['Salary'])
salary.sort()
salary
# Out:
# [1000, 1100, 1300, 1500, 1600, 2000, 2300]

# %%
df.describe()
# Out:
#             Salary
# count     7.000000
# mean   1542.857143
# std     472.077475
# min    1000.000000
# 25%    1200.000000
# 50%    1500.000000
# 75%    1800.000000
# max    2300.000000

# %%
df.groupby([ 'Company','Salary']).size()
# Out:
# Company    Salary
# APPLE      1600      1
#            2300      1
# GOOGLE     1000      1
#            1100      1
# MICROSOFT  1300      1
#            1500      1
# TESLA      2000      1
# dtype: int64

# %%
df[['Company','Salary']].value_counts()
# Out:
# Company    Salary
# APPLE      1600      1
#            2300      1
# GOOGLE     1000      1
#            1100      1
# MICROSOFT  1300      1
#            1500      1
# TESLA      2000      1
# dtype: int64

# %%
df.groupby('Company').describe()
# Out:
#           Salary
#            count    mean         std     min     25%     50%     75%     max
# Company
# APPLE        2.0  1950.0  494.974747  1600.0  1775.0  1950.0  2125.0  2300.0
# GOOGLE       2.0  1050.0   70.710678  1000.0  1025.0  1050.0  1075.0  1100.0
# MICROSOFT    2.0  1400.0  141.421356  1300.0  1350.0  1400.0  1450.0  1500.0
# TESLA        1.0  2000.0         NaN  2000.0  2000.0  2000.0  2000.0  2000.0

# %% [markdown]
# # .loc in Pandas
#
# Access a group of rows and columns by label(s) or a boolean array.
#
# .loc[] is primarily label based, but may also be used with a boolean array.

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.loc[0:4,['Company','Employees']]
# Out:
#      Company   Employees
# 0     GOOGLE      NAVEEN
# 1     GOOGLE       AMOGH
# 2  MICROSOFT     ABHINAV
# 3  MICROSOFT  SHUBHRANIL
# 4      APPLE       Inder

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.loc[1:3]
# Out:
#      Company   Employees  Salary
# 1     GOOGLE       AMOGH    1100
# 2  MICROSOFT     ABHINAV    1500
# 3  MICROSOFT  SHUBHRANIL    1300

# %%
df.groupby('Company').describe()
# Out:
#           Salary
#            count    mean         std     min     25%     50%     75%     max
# Company
# APPLE        2.0  1950.0  494.974747  1600.0  1775.0  1950.0  2125.0  2300.0
# GOOGLE       2.0  1050.0   70.710678  1000.0  1025.0  1050.0  1075.0  1100.0
# MICROSOFT    2.0  1400.0  141.421356  1300.0  1350.0  1400.0  1450.0  1500.0
# TESLA        1.0  2000.0         NaN  2000.0  2000.0  2000.0  2000.0  2000.0

# %%
df.groupby('Company').describe().loc['GOOGLE']['Salary'][['mean','std']]
# Out:
# mean    1050.000000
# std       70.710678
# Name: GOOGLE, dtype: float64

# %%
df[['Company','Employees']]
# Out:
#      Company            Employees
# 0     GOOGLE               NAVEEN
# 1     GOOGLE                AMOGH
# 2  MICROSOFT              ABHINAV
# 3  MICROSOFT           SHUBHRANIL
# 4      APPLE                Inder
# 5      APPLE  sriranganatharajume
# 6      TESLA                Rohit

# %%
# Q2. Apply groupby on microsoft and apply and find the mean and std of these companies.

df.groupby('Company').describe()['Salary'].loc[['APPLE','MICROSOFT'],['mean','std']]
# Out:
#              mean         std
# Company
# APPLE      1950.0  494.974747
# MICROSOFT  1400.0  141.421356

# %%
df.groupby('Company').describe().loc['APPLE']
# Out:
# Salary  count       2.000000
#         mean     1950.000000
#         std       494.974747
#         min      1600.000000
#         25%      1775.000000
#         50%      1950.000000
#         75%      2125.000000
#         max      2300.000000
# Name: APPLE, dtype: float64

# %%
pd.DataFrame(df.groupby('Company').describe().loc['APPLE']).transpose() #tranpose means it will rotate your dataframe by 90 degrees
# Out:
#       Salary
#        count    mean         std     min     25%     50%     75%     max
# APPLE    2.0  1950.0  494.974747  1600.0  1775.0  1950.0  2125.0  2300.0

# %%
df.groupby('Company').size()
# Out:
# Company
# APPLE        2
# GOOGLE       2
# MICROSOFT    2
# TESLA        1
# dtype: int64

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.groupby('Company').agg({"Salary":['min',"max",'mean','sum','std']})
# Out:
#           Salary
#              min   max    mean   sum         std
# Company
# APPLE       1600  2300  1950.0  3900  494.974747
# GOOGLE      1000  1100  1050.0  2100   70.710678
# MICROSOFT   1300  1500  1400.0  2800  141.421356
# TESLA       2000  2000  2000.0  2000         NaN

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
# Q1. Give me the row in the dataframe with employees name as Inder
df[df['Employees']=='Inder']
# Out:
#   Company Employees  Salary
# 4   APPLE     Inder    1600

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000

# %%
df.loc[7]=['TESLA','ALOK',1250]
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000
# 7      TESLA                 ALOK    1250

# %%
(df['Company']=='GOOGLE') & (df['Salary']==1000)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df[ (df['Company']=='GOOGLE') & (df['Salary']==1000) ] #bitwise operation for pandas dataframe
# Out:
#   Company Employees  Salary
# 0  GOOGLE    NAVEEN    1000

# %%
df.dtypes #it gives you the datatype of each column
# Out:
# Company      object
# Employees    object
# Salary        int64
# dtype: object

# %%
#Q2. Give me the row in dataframe where salary is 2000

# %% [markdown]
# # Concat Function: Combining two pandas or more than two dataframe into one

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000
# 7      TESLA                 ALOK    1250

# %%
df2=pd.DataFrame({"Employee_id":[11,21,1212,3232,121221,323232,1221,66],
                  "Benefits":['Bonus',"Bonus","Stocks",'Stocks','Iphone','Iphone','Dogecoin','Dogecoin']}
                )
df2
# Out:
#    Employee_id  Benefits
# 0           11     Bonus
# 1           21     Bonus
# 2         1212    Stocks
# 3         3232    Stocks
# 4       121221    Iphone
# 5       323232    Iphone
# 6         1221  Dogecoin
# 7           66  Dogecoin

# %%
pd.concat([df,df2],axis=0)
# Out:
#      Company            Employees  Salary  Employee_id  Benefits
# 0     GOOGLE               NAVEEN  1000.0          NaN       NaN
# 1     GOOGLE                AMOGH  1100.0          NaN       NaN
# 2  MICROSOFT              ABHINAV  1500.0          NaN       NaN
# 3  MICROSOFT           SHUBHRANIL  1300.0          NaN       NaN
# 4      APPLE                Inder  1600.0          NaN       NaN
# 5      APPLE  sriranganatharajume  2300.0          NaN       NaN
# 6      TESLA                Rohit  2000.0          NaN       NaN
# 7      TESLA                 ALOK  1250.0          NaN       NaN
# 0        NaN                  NaN     NaN         11.0     Bonus
# 1        NaN                  NaN     NaN         21.0     Bonus
# 2        NaN                  NaN     NaN       1212.0    Stocks
# 3        NaN                  NaN     NaN       3232.0    Stocks
# 4        NaN                  NaN     NaN     121221.0    Iphone
# ...

# %% [markdown]
# # Merge function in Pandas
#
# Based on the common column the dataframes are integrated into one

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000
# 7      TESLA                 ALOK    1250

# %%
df_salary={"Salary":[1000,1100,1500,1300,1600,2300,2000,1250],"Employee_id":[11,2121,3,43,54,65,76,87]}
df_salary=pd.DataFrame(df_salary)
df_salary
# Out:
#    Salary  Employee_id
# 0    1000           11
# 1    1100         2121
# 2    1500            3
# 3    1300           43
# 4    1600           54
# 5    2300           65
# 6    2000           76
# 7    1250           87

# %%
pd.concat([df,df_salary],axis=1)
# Out:
#      Company            Employees  Salary  Salary  Employee_id
# 0     GOOGLE               NAVEEN    1000    1000           11
# 1     GOOGLE                AMOGH    1100    1100         2121
# 2  MICROSOFT              ABHINAV    1500    1500            3
# 3  MICROSOFT           SHUBHRANIL    1300    1300           43
# 4      APPLE                Inder    1600    1600           54
# 5      APPLE  sriranganatharajume    2300    2300           65
# 6      TESLA                Rohit    2000    2000           76
# 7      TESLA                 ALOK    1250    1250           87

# %%
merged_df=pd.merge(df,df_salary,on='Salary')
merged_df
# Out:
#      Company            Employees  Salary  Employee_id
# 0     GOOGLE               NAVEEN    1000           11
# 1     GOOGLE                AMOGH    1100         2121
# 2  MICROSOFT              ABHINAV    1500            3
# 3  MICROSOFT           SHUBHRANIL    1300           43
# 4      APPLE                Inder    1600           54
# 5      APPLE  sriranganatharajume    2300           65
# 6      TESLA                Rohit    2000           76
# 7      TESLA                 ALOK    1250           87

# %%
df
# Out:
#      Company            Employees  Salary
# 0     GOOGLE               NAVEEN    1000
# 1     GOOGLE                AMOGH    1100
# 2  MICROSOFT              ABHINAV    1500
# 3  MICROSOFT           SHUBHRANIL    1300
# 4      APPLE                Inder    1600
# 5      APPLE  sriranganatharajume    2300
# 6      TESLA                Rohit    2000
# 7      TESLA                 ALOK    1250

# %%
df['Employee_id']=[1,2,4,65,76,87,98,90]
df
# Out:
#      Company            Employees  Salary  Employee_id
# 0     GOOGLE               NAVEEN    1000            1
# 1     GOOGLE                AMOGH    1100            2
# 2  MICROSOFT              ABHINAV    1500            4
# 3  MICROSOFT           SHUBHRANIL    1300           65
# 4      APPLE                Inder    1600           76
# 5      APPLE  sriranganatharajume    2300           87
# 6      TESLA                Rohit    2000           98
# 7      TESLA                 ALOK    1250           90

# %%
def usd_to_inr(x):
    return x*76

# %%
df['Salary']=df['Salary'].apply(usd_to_inr)
df
# Out:
#      Company            Employees  Salary  Employee_id
# 0     GOOGLE               NAVEEN   76000            1
# 1     GOOGLE                AMOGH   83600            2
# 2  MICROSOFT              ABHINAV  114000            4
# 3  MICROSOFT           SHUBHRANIL   98800           65
# 4      APPLE                Inder  121600           76
# 5      APPLE  sriranganatharajume  174800           87
# 6      TESLA                Rohit  152000           98
# 7      TESLA                 ALOK   95000           90

# %%
df.rename(columns={"Salary":'Salary_in_inr'},inplace=True)
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id
# 0     GOOGLE               NAVEEN          76000            1
# 1     GOOGLE                AMOGH          83600            2
# 2  MICROSOFT              ABHINAV         114000            4
# 3  MICROSOFT           SHUBHRANIL          98800           65
# 4      APPLE                Inder         121600           76
# 5      APPLE  sriranganatharajume         174800           87
# 6      TESLA                Rohit         152000           98
# 7      TESLA                 ALOK          95000           90

# %%
df['Salary_in_inr']=df['Salary_in_inr'].apply(lambda x: 2*x)
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id
# 0     GOOGLE               NAVEEN         152000            1
# 1     GOOGLE                AMOGH         167200            2
# 2  MICROSOFT              ABHINAV         228000            4
# 3  MICROSOFT           SHUBHRANIL         197600           65
# 4      APPLE                Inder         243200           76
# 5      APPLE  sriranganatharajume         349600           87
# 6      TESLA                Rohit         304000           98
# 7      TESLA                 ALOK         190000           90

# %%
df[['Employees','Employee_id','Salary_in_inr','Company']]
# Out:
#              Employees  Employee_id  Salary_in_inr    Company
# 0               NAVEEN            1         152000     GOOGLE
# 1                AMOGH            2         167200     GOOGLE
# 2              ABHINAV            4         228000  MICROSOFT
# 3           SHUBHRANIL           65         197600  MICROSOFT
# 4                Inder           76         243200      APPLE
# 5  sriranganatharajume           87         349600      APPLE
# 6                Rohit           98         304000      TESLA
# 7                 ALOK           90         190000      TESLA

# %%
#Q. Find the total sum of the Salary in inr column
df['Salary_in_inr'].sum()
# Out:
# 1831600

# %%
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id
# 0     GOOGLE               NAVEEN         152000            1
# 1     GOOGLE                AMOGH         167200            2
# 2  MICROSOFT              ABHINAV         228000            4
# 3  MICROSOFT           SHUBHRANIL         197600           65
# 4      APPLE                Inder         243200           76
# 5      APPLE  sriranganatharajume         349600           87
# 6      TESLA                Rohit         304000           98
# 7      TESLA                 ALOK         190000           90

# %%
df['Sales']=[5,10,12,3,4,12,21,0]
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id  Sales  \
# 0     GOOGLE               NAVEEN         152000            1      5
# 1     GOOGLE                AMOGH         167200            2     10
# 2  MICROSOFT              ABHINAV         228000            4     12
# 3  MICROSOFT           SHUBHRANIL         197600           65      3
# 4      APPLE                Inder         243200           76      4
# 5      APPLE  sriranganatharajume         349600           87     12
# 6      TESLA                Rohit         304000           98     21
# 7      TESLA                 ALOK         190000           90      0
#
#    Money_per_sale
# 0    30400.000000
# 1    16720.000000
# 2    19000.000000
# 3    65866.666667
# 4    60800.000000
# 5    29133.333333
# 6    14476.190476
# 7     3518.518519

# %%
df['Sales'].divide(df['Money_per_sale'])
# Out:
# 0    0.000164
# 1    0.000598
# 2    0.000632
# 3    0.000046
# 4    0.000066
# 5    0.000412
# 6    0.001451
# 7    0.000000
# dtype: float64

# %%
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id  Sales  \
# 0     GOOGLE               NAVEEN         152000            1      5
# 1     GOOGLE                AMOGH         167200            2     10
# 2  MICROSOFT              ABHINAV         228000            4     12
# 3  MICROSOFT           SHUBHRANIL         197600           65      3
# 4      APPLE                Inder         243200           76      4
# 5      APPLE  sriranganatharajume         349600           87     12
# 6      TESLA                Rohit         304000           98     21
# 7      TESLA                 ALOK         190000           90      0
#
#    Money_per_sale
# 0    30400.000000
# 1    16720.000000
# 2    19000.000000
# 3    65866.666667
# 4    60800.000000
# 5    29133.333333
# 6    14476.190476
# 7     3518.518519

# %%
for i in df.index:
    print("The sales is------",df.loc[i]['Sales'])
    print("THE SALARY in-------",df.loc[i]['Salary_in_inr'])
    if df.loc[i]['Sales']>0:
        print("The income per sales",df.loc[i]['Salary_in_inr']/df.loc[i]['Sales'])
    if df.loc[i]['Sales']>0:
        print("divide")
        df.loc[i]['Money_per_sale']=(df.loc[i]['Salary_in_inr']/df.loc[i]['Sales'])
    else:
        df.loc[i]['Money_per_sale']=0
df
# Out:
# The sales is------ 5
# THE SALARY in------- 152000
# The income per sales 30400.0
# divide
# The sales is------ 10
# THE SALARY in------- 167200
# The income per sales 16720.0
# divide
# The sales is------ 12
# THE SALARY in------- 228000
# The income per sales 19000.0
# divide
# The sales is------ 3
# THE SALARY in------- 197600
# The income per sales 65866.66666666667
# divide
# The sales is------ 4
# THE SALARY in------- 243200
# The income per sales 60800.0
# divide
# The sales is------ 12
# THE SALARY in------- 349600
# The income per sales 29133.333333333332
# divide
# The sales is------ 21
# THE SALARY in------- 304000
# The income per sales 14476.190476190477
# divide
# The sales is------ 0
# THE SALARY in------- 190000
# C:\Users\sidak\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# # Q. How much money each person makes from each sales.
# if df['Sales']>0:
#     df['Money_per_sale']=(df['Salary_in_inr']/df['Sales'])
# else:
#     df['Money_per_sale']=0
# df

# %%
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id  Sales  \
# 0     GOOGLE               NAVEEN         152000            1      5
# 1     GOOGLE                AMOGH         167200            2     10
# 2  MICROSOFT              ABHINAV         228000            4     12
# 3  MICROSOFT           SHUBHRANIL         197600           65      3
# 4      APPLE                Inder         243200           76      4
# 5      APPLE  sriranganatharajume         349600           87     12
# 6      TESLA                Rohit         304000           98     21
# 7      TESLA                 ALOK         190000           90      0
#
#    Money_per_sale
# 0    30400.000000
# 1    16720.000000
# 2    19000.000000
# 3    65866.666667
# 4    60800.000000
# 5    29133.333333
# 6    14476.190476
# 7     3518.518519

# %% [markdown]
# # iloc Function in pandas

# %% [markdown]
# Purely integer-location based indexing for selection by position.
#
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
df
# Out:
#      Company            Employees  Salary_in_inr  Employee_id  Sales  \
# 0     GOOGLE               NAVEEN         152000            1      5
# 1     GOOGLE                AMOGH         167200            2     10
# 2  MICROSOFT              ABHINAV         228000            4     12
# 3  MICROSOFT           SHUBHRANIL         197600           65      3
# 4      APPLE                Inder         243200           76      4
# 5      APPLE  sriranganatharajume         349600           87     12
# 6      TESLA                Rohit         304000           98     21
# 7      TESLA                 ALOK         190000           90      0
#
#    Money_per_sale
# 0    30400.000000
# 1    16720.000000
# 2    19000.000000
# 3    65866.666667
# 4    60800.000000
# 5    29133.333333
# 6    14476.190476
# 7     3518.518519

# %%
df.loc[1:4,2:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6656/4157982305.py in <module>
# ----> 1 df.loc[1:4,2:4]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
df.iloc[1:4,2:4] #iloc function just requires the numerical index
# Out:
#    Salary_in_inr  Employee_id
# 1         167200            2
# 2         228000            4
# 3         197600           65

# %%
df.iloc[0:2,0:3] #in iloc the end point is not inclusive like indexing
# Out:
#   Company Employees  Salary_in_inr
# 0  GOOGLE    NAVEEN         152000
# 1  GOOGLE     AMOGH         167200

# %%
df.loc[1:4]
# Out:
#      Company   Employees  Salary_in_inr  Employee_id  Sales  Money_per_sale
# 1     GOOGLE       AMOGH         167200            2     10    16720.000000
# 2  MICROSOFT     ABHINAV         228000            4     12    19000.000000
# 3  MICROSOFT  SHUBHRANIL         197600           65      3    65866.666667
# 4      APPLE       Inder         243200           76      4    60800.000000
